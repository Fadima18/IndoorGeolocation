# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
times = np.random.rand(100)
times
# Out:
# array([0.93835294, 0.3753372 , 0.05270965, 0.94913558, 0.31187032,
#        0.37626068, 0.79019432, 0.71127287, 0.08738438, 0.17064408,
#        0.00975759, 0.5410849 , 0.77557612, 0.21243541, 0.90925277,
#        0.20131561, 0.2695284 , 0.81949043, 0.81153649, 0.44420358,
#        0.37304085, 0.06443709, 0.92294471, 0.9557056 , 0.34134735,
#        0.48953375, 0.14426731, 0.15205352, 0.9645396 , 0.06510714,
#        0.6515302 , 0.99355858, 0.72412148, 0.97082775, 0.15697656,
#        0.35930776, 0.38523307, 0.52993262, 0.0763147 , 0.1134813 ,
#        0.99488294, 0.3831284 , 0.67465962, 0.87333684, 0.24531425,
#        0.19714481, 0.72933237, 0.54610435, 0.76152215, 0.50929079,
#        0.54100232, 0.90410293, 0.46076385, 0.8386763 , 0.55425314,
#        0.97246325, 0.94422528, 0.78571988, 0.53616893, 0.69178112,
#        0.83914965, 0.97589317, 0.39591311, 0.6450825 , 0.43568387,
#        0.82019449, 0.42216781, 0.20329531, 0.98197869, 0.26080453,
#        0.72628822, 0.67747894, 0.42415566, 0.76287504, 0.10073006,
#        0.25477418, 0.98838563, 0.52532569, 0.31366351, 0.37409483,
#        0.13508164, 0.34888449, 0.67065433, 0.13779365, 0.0574723 ,
#        0.29303591, 0.47888268, 0.55960945, 0.25924672, 0.90383331,
#        0.84213596, 0.95122501, 0.8431559 , 0.85075421, 0.35113269,
#        0.82276801, 0.46104092, 0.92380405, 0.06439143, 0.11027487])

# %%
plt.figure(figsize=(14,7)) 
plt.style.use('seaborn-whitegrid')
n, bins, patches = plt.hist(times, list(range(40)), facecolor = '#2ab0ff', edgecolor='#169acf', linewidth=0.5)
n = n.astype('int') # it MUST be integer
# Good old loop. Choose colormap of your taste
for i in range(len(patches)):
    patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))

# %%
def deci2bin(x):
    tab = []
    while (x//2) != 0:
        tab.append(x%2)
        x = x//2
    tab.append(x%2)
    n = len(tab)
    for i in range(n-1, -1, -1):
        print(tab[i], end='')
